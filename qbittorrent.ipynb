# %% [markdown]
# # Mount!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Prepare environment

# %%
# !bash 'the place of qbittorrent.sh file'

# %% [markdown]
# # Main

# %%
from qbmain import torrent
try:
  torrent()
except:
  pass

# %% [markdown]
# # Else

# %%
from qbmain import qb, get_size_format
torrents = qb.torrents(filter='downloading')
for torrent in torrents:
  print(torrent['name'])
  print(get_size_format(torrent['downloaded']))
